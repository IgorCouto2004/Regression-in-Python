# %%
import pandas as pd
import sklearn.model_selection as ms
import matplotlib.pyplot as plt
import sklearn.linear_model
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
dados = pd.read_csv('MKT.csv')
dados.head()
# Out:
#    youtube  facebook  newspaper  sales
# 0    84.72     19.20      48.96  12.60
# 1   351.48     33.96      51.84  25.68
# 2   135.48     20.88      46.32  14.28
# 3   116.64      1.80      36.00  11.52
# 4   318.72     24.00       0.36  20.88

# %%
dados.tail()
# Out:
#      youtube  facebook  newspaper  sales
# 166    45.84      4.44      16.56   9.12
# 167   113.04      5.88       9.72  11.64
# 168   212.40     11.16       7.68  15.36
# 169   340.32     50.40      79.44  30.60
# 170   278.52     10.32      10.44  16.08

# %%
dados.dropna()
# Out:
#      youtube  facebook  newspaper  sales
# 0      84.72     19.20      48.96  12.60
# 1     351.48     33.96      51.84  25.68
# 2     135.48     20.88      46.32  14.28
# 3     116.64      1.80      36.00  11.52
# 4     318.72     24.00       0.36  20.88
# ..       ...       ...        ...    ...
# 166    45.84      4.44      16.56   9.12
# 167   113.04      5.88       9.72  11.64
# 168   212.40     11.16       7.68  15.36
# 169   340.32     50.40      79.44  30.60
# 170   278.52     10.32      10.44  16.08
#
# [171 rows x 4 columns]

# %%
dados.describe()
# Out:
#           youtube    facebook   newspaper       sales
# count  171.000000  171.000000  171.000000  171.000000
# mean   178.021053   27.671579   35.240000   16.922807
# std    102.449597   17.913532   24.902918    6.314608
# min      0.840000    0.000000    0.360000    1.920000
# 25%     91.080000   11.700000   13.740000   12.540000
# 50%    179.760000   26.760000   31.080000   15.480000
# 75%    262.980000   43.680000   50.880000   20.820000
# max    355.680000   59.520000  121.080000   32.400000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtube    171 non-null    float64
#  1   facebook   171 non-null    float64
#  2   newspaper  171 non-null    float64
#  3   sales      171 non-null    float64
# dtypes: float64(4)
# memory usage: 5.5 KB

# %%
dados.isnull().sum()
# Out:
# youtube      0
# facebook     0
# newspaper    0
# sales        0
# dtype: int64

# %%
dados['sales'].mean()
# Out:
# 16.922807017543857

# %%
dados[['sales', 'youtube', 'facebook', 'newspaper']].median()
# Out:
# sales         15.48
# youtube      179.76
# facebook      26.76
# newspaper     31.08
# dtype: float64

# %%
dados.corr()['sales']
# Out:
# youtube      0.782030
# facebook     0.602918
# newspaper    0.254987
# sales        1.000000
# Name: sales, dtype: float64

# %%
import seaborn as sns

# %%
sns.pairplot(dados, x_vars = ['youtube', 'facebook', 'newspaper'], y_vars='sales')

# %%
sns.histplot(dados["sales"])
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %%
X = dados[['youtube', 'facebook', 'newspaper']]

Y = dados['sales']

# %%
X_train, X_test, Y_train, Y_test = ms.train_test_split(X, Y, test_size=0.7)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (51, 3)
# (120, 3)
# (51,)
# (120,)

# %%
reg = lm.LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
r = r2_score(Y_test, y_pred)

# %%
print("r_quadrado:", r)
# Out:
# r_quadrado: 0.8779203274880732

# %%
c = [i for i in range(0, 120, 1)]
fig = plt.figure(figsize=(12,8))
plt.plot(c, Y_test, color="yellow")
plt.plot(c, y_pred, color="orange")
plt.xlabel("Plataformas")
plt.ylabel("Valor das Vendas")
# Out:
# Text(0, 0.5, 'Valor das Vendas')

# %%
youtube = 178
facebook = 27
newspaper = 35

valores = [[youtube, facebook, newspaper]]
reg.predict(valores)[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# 16.972933802524267
